# %% [markdown]
# # Iris Dataset Project

# %% [markdown]
# # Task- 3

# %% [markdown]
# # Import numpy and pandas

# %%
# importing standard lib..
import numpy as np
import pandas as pd

# %% [markdown]
# # Import visualization libraries and set %matplotlib inline.

# %%
# Importing visualization libraries and set %matplotlib inline.
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Read in the csv file as a dataframe called df

# %%
# Reading a csv file
df=pd.read_csv("E:\\python\\iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Check the info() of the df

# %%
# Checking information about dataset by using info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.3+ KB

# %% [markdown]
# # Check the head of df

# %%
#head() is use to check head of Dataframe
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Check whether the dataset contains some null values using .isnull() method.¶
# Also use .count() method to display the count for the same.

# %%
#here we check the null values in the dataset

df.isnull().count()
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# species         150
# dtype: int64

# %% [markdown]
# # Use .describe() method to describe the dataset

# %%
#here we use .describe()method to describe the dataset

df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Understanding Data

# %%
# Print the no of rows and column
df.shape
# Out:
# (150, 5)

# %%
# Checking the columns names in dataset
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# Here we check the type of species dataset have using nunique()
df['species'].nunique()
# Out:
# 3

# %%
# print types of species
df["species"].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %%
# calculating sum of all with respect to species using groupby() func.
df.groupby('species').sum()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             250.3        170.9          73.2         12.2
# versicolor         296.8        138.5         213.0         66.3
# virginica          329.4        148.7         277.6        101.3

# %%
#calculating mean of all with respect to species using groupby() func.
df.groupby('species').mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.418         1.464        0.244
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %% [markdown]
# # Now, let us try to sort the data in the dataset

# %%
#here we use sorting to sort the data in the dataset
df.sort_values(by = 'sepal_length')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
df.sort_values(by = 'petal_width')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 32            5.2          4.1           1.5          0.1     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 37            4.9          3.1           1.5          0.1     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ..            ...          ...           ...          ...        ...
# 140           6.7          3.1           5.6          2.4  virginica
# 114           5.8          2.8           5.1          2.4  virginica
# 100           6.3          3.3           6.0          2.5  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 109           7.2          3.6           6.1          2.5  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # catergorising data in a column in dataset using .size() method

# %%
make_dist1 = df.groupby('sepal_length').size()
make_dist1
# Out:
# sepal_length
# 4.3     1
# 4.4     3
# 4.5     1
# 4.6     4
# 4.7     2
# 4.8     5
# 4.9     6
# 5.0    10
# 5.1     9
# 5.2     4
# 5.3     1
# 5.4     6
# 5.5     7
# 5.6     6
# 5.7     8
# 5.8     7
# 5.9     3
# 6.0     6
# 6.1     6
# 6.2     4
# 6.3     9
# 6.4     7
# 6.5     5
# 6.6     2
# 6.7     8
# 6.8     3
# 6.9     4
# 7.0     1
# 7.1     1
# 7.2     3
# 7.3     1
# 7.4     1
# 7.6     1
# 7.7     4
# 7.9     1
# dtype: int64

# %% [markdown]
# # Now use seaborn to create a countplot of Irisdataset by species.

# %%
make_dist2 = df.groupby('sepal_width').size()
make_dist2
# Out:
# sepal_width
# 2.0     1
# 2.2     3
# 2.3     4
# 2.4     3
# 2.5     8
# 2.6     5
# 2.7     9
# 2.8    14
# 2.9    10
# 3.0    26
# 3.1    12
# 3.2    13
# 3.3     6
# 3.4    12
# 3.5     6
# 3.6     3
# 3.7     3
# 3.8     6
# 3.9     2
# 4.0     1
# 4.1     1
# 4.2     1
# 4.4     1
# dtype: int64

# %%
make_dist3 = df.groupby('petal_length').size()
make_dist3
# Out:
# petal_length
# 1.0     1
# 1.1     1
# 1.2     2
# 1.3     7
# 1.4    12
# 1.5    14
# 1.6     7
# 1.7     4
# 1.9     2
# 3.0     1
# 3.3     2
# 3.5     2
# 3.6     1
# 3.7     1
# 3.8     1
# 3.9     3
# 4.0     5
# 4.1     3
# 4.2     4
# 4.3     2
# 4.4     4
# 4.5     8
# 4.6     3
# 4.7     5
# 4.8     4
# 4.9     5
# 5.0     4
# 5.1     8
# 5.2     2
# 5.3     2
# 5.4     2
# 5.5     3
# 5.6     6
# 5.7     3
# 5.8     3
# 5.9     2
# 6.0     2
# 6.1     3
# 6.3     1
# 6.4     1
# 6.6     1
# 6.7     2
# 6.9     1
# dtype: int64

# %%
make_dist4 = df.groupby('petal_width').size()
make_dist4
# Out:
# petal_width
# 0.1     6
# 0.2    28
# 0.3     7
# 0.4     7
# 0.5     1
# 0.6     1
# 1.0     7
# 1.1     3
# 1.2     5
# 1.3    13
# 1.4     8
# 1.5    12
# 1.6     4
# 1.7     2
# 1.8    12
# 1.9     5
# 2.0     6
# 2.1     6
# 2.2     3
# 2.3     8
# 2.4     3
# 2.5     3
# dtype: int64

# %% [markdown]
# # Now plot a distance plot using matplotlib on the iris dataset

# %%
make_dist1.plot(title='sepal_length')

# %%
make_dist1.plot(title='sepal_width',color='Red')

# %%
make_dist1.plot(title='petal_length',color='yellow')

# %%
make_dist1.plot(title='petal_width',color='violet')

# %%
# Here we plot countpot to analyse no of species
# an from graph we see observe there is same no species in dataset 
sns.countplot(x='species',data=df)

# %% [markdown]
# # 1D Scatter plot

# %%
# Here we plot 1d scatter plot 
# Blue colour indicate setosa orange colour indicate verginica and greeen colour indicate versicolour
# we notice that verginica and versicolour ir overlapping each other
df_setso = df.loc[df["species"] == "setosa"];
df_virginica = df.loc[df["species"] == "virginica"];
df_versicolor = df.loc[df["species"] == "versicolor"];
plt.plot(df_setso["petal_length"],np.zeros_like(df_setso["petal_length"]), 'o')
plt.plot(df_versicolor["petal_length"],np.zeros_like(df_versicolor["petal_length"]), 'o')
plt.plot(df_virginica["petal_length"],np.zeros_like(df_virginica["petal_length"]), 'o')
plt.grid()
plt.show()

# %% [markdown]
# # 2D scatter plot

# %%
# we plot 2d scatter plot between sepal_lenght and sepal_width
plt.scatter(df['sepal_length'],df['sepal_width'])
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %% [markdown]
# # 2D scatter plot using colour

# %%
# As in above graph it was difficult to analyse graph so we use seaborn to analyse it more perfectly
# we can distinguish Setosa flowers from others.
# sperating verginica and versicolour is not easy as it is overlapping each other
sns.set_style("whitegrid");
sns.FacetGrid(df,hue="species",height=4) \
 .map(plt.scatter,"sepal_length","sepal_width") \
 .add_legend()

# %% [markdown]
# # 3d scatter plot

# %%
# Displaying 3d plot between sepal_lenght ,sepal_width,petal_length
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(df['sepal_length'],df['sepal_width'], df['petal_length']);

# %% [markdown]
# # BoxPlot Between species and sepal_length

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df['species'],y=df['sepal_length'])

# %% [markdown]
# # BoxPlot Between species and petal_length

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df['species'],y=df['petal_length'])

# %% [markdown]
# # Use Seaborn to plot a catplot for Iris data

# %%
sns.catplot(x='sepal_length', data=df, kind='count', height = 6, aspect = 3.5)

# %% [markdown]
# # Pair plots

# %%
#petal length and petal width are the most useful features to identify various flower types.
#While Setosa can be easily identified (linearly separable), virginica and Versicolor have
#some overlap (almost linearly separable).
sns.pairplot(df,hue="species");

# %% [markdown]
# # Violin Plot

# %%
sns.violinplot(x=df['species'],y=df['sepal_length'])

# %%
sns.violinplot(x=df['species'],y=df['petal_length'])

# %% [markdown]
# # Finding optimum no. of cluster

# %% [markdown]
# ### Ploting Elbow plot

# %%
# Finding the optimum number of clusters for k-means classification

x = df.iloc[:, [0, 1, 2, 3]].values

from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
    
# Plotting the results onto a line graph, 
# `allowing us to observe 'The elbow'
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') # Within cluster sum of squares
plt.show()

# %% [markdown]
# ### Applying K_mean Algorithm to Dataset

# %%
# Applying kmeans to the dataset / Creating the kmeans classifier
kmeans = KMeans(n_clusters = 3, init = 'k-means++',
                max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x)

# %% [markdown]
# ### Visualising the clusters and Plotting the centroids of the clusters with the help of scatter plot

# %%
# Visualising the clusters - On the first two columns
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], 
            s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], 
            s = 100, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1],
            s = 100, c = 'green', label = 'Iris-virginica')

# Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend()

# %% [markdown]
# # Thank You
