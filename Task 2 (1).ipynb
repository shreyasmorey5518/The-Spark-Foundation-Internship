# %% [markdown]
# # Task-2

# %% [markdown]
# ## EDA on SampleSuperstore

# %% [markdown]
# ### Importing Standard Library

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Importing dataset

# %%
# Reading csv file
df=pd.read_csv("SampleSuperstore.csv")
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
# Getting information about dataset usinf .info() function
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 702.8+ KB

# %%
# Describing dataset
df.describe()
# it use to desrcibe whole data_set 
# count= it will give total count of parameter in specific columns
# mean= it will give average value of parameter in specific columns
# min= it will give minimum value of parameter in specific columns
# max= it will give maximum value of parameter in specific columns
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
# Getting some co-relation with the parameter 
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
# Ploting hearmap with the help of cor-relation we get
sns.heatmap(df.corr(),cmap="YlGnBu")

# %%
#checking columns of dataset we have 
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
# Getiing dimension of dataset
df.shape
# Out:
# (9994, 13)

# %%
# Checking any null value is present or not 
df.isnull().sum()
# as we can observe dataset didn't have any null video
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# Checking head of dataset
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# Getting count of highest no Sales with respect to state in dataset  
df['State'].value_counts()
# california have highest no sale foow by other state
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
#simillarly checking for city 
df['City'].value_counts()
# New york city has highest no of sale in dataset
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
#                 ...
# San Mateo          1
# Lindenhurst        1
# Champaign          1
# Commerce City      1
# Yucaipa            1
# Name: City, Length: 531, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
# checking the no o category we have
df['Category'].value_counts()
# office supplies have highest no. sales w.r.t to other category
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
# here we create specific dataframe for specific Category in dataset 
# to check the value of different parameter of specific Category specially
Furniture_data=df[df['Category']=='Furniture']
Office_Supplies_data=df[df['Category']=='Office Supplies']
Technology_data=df[df['Category']=='Technology']

# %%
# here we check the dataframe of Furniture Category
Furniture_data.head()
# Out:
#          Ship Mode   Segment        Country             City       State  \
# 0     Second Class  Consumer  United States        Henderson    Kentucky
# 1     Second Class  Consumer  United States        Henderson    Kentucky
# 3   Standard Class  Consumer  United States  Fort Lauderdale     Florida
# 5   Standard Class  Consumer  United States      Los Angeles  California
# 10  Standard Class  Consumer  United States      Los Angeles  California
#
#     Postal Code Region   Category Sub-Category      Sales  Quantity  Discount  \
# 0         42420  South  Furniture    Bookcases   261.9600         2      0.00
# 1         42420  South  Furniture       Chairs   731.9400         3      0.00
# 3         33311  South  Furniture       Tables   957.5775         5      0.45
# 5         90032   West  Furniture  Furnishings    48.8600         7      0.00
# 10        90032   West  Furniture       Tables  1706.1840         9      0.20
#
#       Profit
# 0    41.9136
# 1   219.5820
# 3  -383.0310
# ...

# %%
# here we check the dataframe of Office_Supplies Category
Office_Supplies_data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 2    Second Class  Corporate  United States      Los Angeles  California
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 2        90036   West  Office Supplies       Labels   14.620         2
# 4        33311  South  Office Supplies      Storage   22.368         2
# 6        90032   West  Office Supplies          Art    7.280         4
# 8        90032   West  Office Supplies      Binders   18.504         3
# 9        90032   West  Office Supplies   Appliances  114.900         5
#
#    Discount   Profit
# 2       0.0   6.8714
# 4       0.2   2.5164
# 6       0.0   1.9656
# ...

# %%
# here we check the dataframe of Technology Category
Technology_data.head()
# Out:
#          Ship Mode    Segment        Country           City       State  \
# 7   Standard Class   Consumer  United States    Los Angeles  California
# 11  Standard Class   Consumer  United States    Los Angeles  California
# 19    Second Class   Consumer  United States  San Francisco  California
# 26    Second Class   Consumer  United States    Los Angeles  California
# 35     First Class  Corporate  United States     Richardson       Texas
#
#     Postal Code   Region    Category Sub-Category     Sales  Quantity  \
# 7         90032     West  Technology       Phones   907.152         6
# 11        90032     West  Technology       Phones   911.424         4
# 19        94109     West  Technology       Phones   213.480         3
# 26        90049     West  Technology  Accessories    90.570         3
# 35        75080  Central  Technology       Phones  1097.544         7
#
#     Discount    Profit
# 7        0.2   90.7152
# 11       0.2   68.3568
# 19       0.2   16.0110
# ...

# %% [markdown]
# ### Ploting Distances plot for different parameter in dataset

# %%
# here we groupby state column w.r.t size to plot Distances Plot 
make_distance1 = df.groupby('State').size()
make_distance1
# Out:
# State
# Alabama                   61
# Arizona                  224
# Arkansas                  60
# California              2001
# Colorado                 182
# Connecticut               82
# Delaware                  96
# District of Columbia      10
# Florida                  383
# Georgia                  184
# Idaho                     21
# Illinois                 492
# Indiana                  149
# Iowa                      30
# Kansas                    24
# Kentucky                 139
# Louisiana                 42
# Maine                      8
# Maryland                 105
# Massachusetts            135
# Michigan                 255
# Minnesota                 89
# Mississippi               53
# Missouri                  66
# Montana                   15
# Nebraska                  38
# Nevada                    39
# New Hampshire             27
# New Jersey               130
# New Mexico                37
# New York                1128
# North Carolina           249
# ...

# %%
# from observation we can say that calefornia has highest no. of sale 

make_distance1.plot(title='State_Count',c='r')

# %%
make_distance2=df.groupby('Region').size()
make_distance2
# Out:
# Region
# Central    2323
# East       2848
# South      1620
# West       3203
# dtype: int64

# %%
make_distance2.plot(title='Region_Count',c='y')

# %%
make_distance3=df.groupby('Category').size()
make_distance3
# Out:
# Category
# Furniture          2121
# Office Supplies    6026
# Technology         1847
# dtype: int64

# %%
make_distance3.plot(title='Category_count',c='g')

# %% [markdown]
# ### Line plot on the basis of profit made by store

# %%
plt.figure(figsize=(10,5))
plt.plot(df['Profit'],color='Green')
plt.grid(alpha=2)

# %% [markdown]
# ### Barplot between Sub-category and category

# %%
# from plot we can say that technology category has highest no sale
# furniture has lowest no. of sale 
plt.figure(figsize=(15,5))
plt.bar('Sub-Category','Category', data=df)
plt.xticks(rotation=90)

plt.show()

# %%
# Countplot to check highest sale w.r.t various state
plt.figure(figsize=(15,8))
sns.countplot(x=df['State'])
plt.xticks(rotation=90)
plt.show()
# we can observe that california has highest no sale w.r.t to other state
# Vyoming  has lowest no. if state

# %%
# countplot to check highest no. of count of sub-category 
plt.figure(figsize=(12,6))
sns.countplot(x=df['Sub-Category'])
plt.xticks(rotation=90)
plt.show()
# Blinder has a highest no. of sale as compared to other

# %% [markdown]
# ### Distribution base on Segments and Ship mode

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(x='Segment',data=df)
plt.title('Distribution of Segments')
plt.subplot(1,2,2)
sns.countplot(x='Ship Mode',data=df)
plt.title('Dstribution of Ship Mode')
plt.show()

# %% [markdown]
# ### Distribution based on Region/Category

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.countplot('Region',data=df)
plt.title('Distribution of Regions')
plt.subplot(1,2,2)
sns.countplot('Region',hue='Category',data=df)
plt.title('Distribution of Categories')
plt.show()

# %% [markdown]
# ### Distribution based on Categories/Sub-Categories

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,1,1)
sns.countplot('Category',data=df)
plt.title('Distribution of Categories',fontsize=18)
plt.subplot(2,1,2)
sns.countplot('Sub-Category',data=df)
plt.title('Distribution of Sub-Category',fontsize=18)
plt.show()

# %% [markdown]
# ### Boxplot

# %%
plt.figure(figsize=(10,5))
sns.set(style="whitegrid")
sns.boxplot(x='Sales', y='Category', data=df, hue='Region')

# %% [markdown]
# # Pairplot between all columns of dataset

# %%
sns.pairplot(data=df)

# %% [markdown]
# # Thank You
